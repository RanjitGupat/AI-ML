# %% [markdown]
# <a href="https://colab.research.google.com/github/RanjitGupat/AI-ML/blob/main/JoinData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
var1 = pd.DataFrame({"A":[1,2,4,3,9,0],
                      "B":[5,6,7,9,3,5]})
var2 = pd.DataFrame({"C":[12,14,15,2,7,8],
                      "D":[15,16,18,9,3,7]})
var1
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  4  7
# 3  3  9
# 4  9  3
# 5  0  5

# %%
var2
# Out:
#     C   D
# 0  12  15
# 1  14  16
# 2  15  18
# 3   2   9
# 4   7   3
# 5   8   7

# %%
var1.join(var2)
# Out:
#    A  B   C   D
# 0  1  5  12  15
# 1  2  6  14  16
# 2  4  7  15  18
# 3  3  9   2   9
# 4  9  3   7   3
# 5  0  5   8   7

# %%
import pandas as pd
var3 = pd.DataFrame({"A":[1,2,4,3,9,0],
                      "B":[5,6,7,9,3,5]},index=["a","b","c","d","e","f"])
var4 = pd.DataFrame({"C":[12,14,15,2,7,8],
                      "D":[15,16,18,9,3,7]},index=["a","b","c","d","e","f"])

# %%
var1.join(var2)
# Out:
#    A  B   C   D
# 0  1  5  12  15
# 1  2  6  14  16
# 2  4  7  15  18
# 3  3  9   2   9
# 4  9  3   7   3
# 5  0  5   8   7
